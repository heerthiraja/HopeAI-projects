# %%
import pandas as pd

# %%
dataset=pd.read_csv("Pre_processed_Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
dataset.isna().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dir(dataset)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
dataset.cov()
#The Covariance between degree passmark and Etest passmark is "Positive Covariance"- the difference is 21%.
#The Covariane between Etest passmark and MBA passmark is "Positive Covariance"- the difference is 16%.
# Out:
#                  sl_no          ssc_p          hsc_p       degree_p  \
# sl_no      3870.000000     -52.641355     -59.598879     -41.465047
# ssc_p       -52.641355     117.228377      58.853253      42.702550
# hsc_p       -59.598879      58.853253     112.063731      33.684453
# degree_p    -41.465047      42.702550      33.684453      53.604710
# etest_p      52.556168      37.659225      33.838355      22.078774
# mba_p         8.102336      24.535952      21.517688      17.185200
# salary    11383.177570  908858.485818  731007.850848  466336.264888
#
#                 etest_p          mba_p        salary
# sl_no         52.556168       8.102336  1.138318e+04
# ssc_p         37.659225      24.535952  9.088585e+05
# hsc_p         33.838355      21.517688  7.310079e+05
# degree_p      22.078774      17.185200  4.663363e+05
# etest_p      176.251018      16.886973  3.727004e+05
# mba_p         16.886973      34.028376  1.239934e+05
# ...

# %%
dataset.corr()
#Correlation-Relationship between 2 columns mba_p,salary is Positive correlation,14% directly proportional
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.090500 -0.091039  0.063636  0.022327  0.001217
# ssc_p    -0.078155  1.000000  0.513478  0.538686  0.261993  0.388478  0.558475
# hsc_p    -0.090500  0.513478  1.000000  0.434606  0.240775  0.348452  0.459424
# degree_p -0.091039  0.538686  0.434606  1.000000  0.227147  0.402376  0.423762
# etest_p   0.063636  0.261993  0.240775  0.227147  1.000000  0.218055  0.186775
# mba_p     0.022327  0.388478  0.348452  0.402376  0.218055  1.000000  0.141417
# salary    0.001217  0.558475  0.459424  0.423762  0.186775  0.141417  1.000000

# %%
dataset.drop("sl_no",inplace=True,axis=1)
#inplace for we dont assign assignment operator so after the drop the changes will be save in the dataset and for columnwise in axis.

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(dataset)
#pairplot is for 2 columns.
#most important when u see a graph to understand the data

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):

    #calculating VIF
    vif=pd.DataFrame()
    vif["variables"]=X.columns
    vif["VIF"]=[variance_inflation_factor(X.values,i)for i in range(X.shape[1])]
    
    return(vif)

# %%
#Explanation of variance inflation factor
#In firstline import variance inflation factor from statsmodel
#In secondline Define a function
#In third line Then create a table 
#In fourth line What we give input that is act as a column name that is create as a variable
#In fifth line first execute the oneliner for loop, Shape indicates Number of rows and columns ,
#shape[1] so it take column ,after that no.of values that are go to X.values then we calculate variance inflation factor
#after the calculation its stored in vif

# %%
 calc_vif(dataset[["etest_p","salary"]])
# Out:
#   variables       VIF
# 0   etest_p  2.826904
# 1    salary  2.826904

# %%
dataset.columns
# Out:
# Index(['gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p',
#        'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p', 'status',
#        'salary'],
#       dtype='object')

# %%
dataset[dataset["gender"]=="M"]
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 209      M  62.00  Central  72.00  Central  Commerce     65.00  Comm&Mgmt
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
dataset[dataset['gender']=='F']["salary"]
# Out:
# 6           0
# 12          0
# 13     218000
# 15     200000
# 17          0
#         ...
# 197    260000
# 198         0
# 204    210000
# 208         0
# 213    204000
# Name: salary, Length: 76, dtype: int64

# %% [markdown]
# ## Independent Sample- Unpaired T- Test
# ### Different Group(male,female) but same condition(salary)

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
male=dataset[dataset['gender']=='M']["salary"]
female=dataset[dataset['gender']=='F']["salary"]
#print(MALE)
ttest_ind(male,female)
# Out:
# Ttest_indResult(statistic=2.0937842507001165, pvalue=0.03746230397067219)

# %% [markdown]
# ### The P value is 3% so it is good

# %% [markdown]
# ### Assignment

# %%
from scipy.stats import ttest_ind
#drop null values
dataset=dataset.dropna()
commerce=dataset[dataset["hsc_s"]=="Commerce"]["mba_p"]
science=dataset[dataset["hsc_s"]=="Science"]["mba_p"]
#print(male)
ttest_ind(commerce,science)
# Out:
# Ttest_indResult(statistic=-0.7331285580404581, pvalue=0.46432995253854314)

# %%
from scipy.stats import ttest_ind
#drop null values
dataset=dataset.dropna()
others=dataset[dataset["hsc_b"]=="Others"]["salary"]
central=dataset[dataset["hsc_b"]=="Central"]["salary"]
#print(male)
ttest_ind(others,central)
# Out:
# Ttest_indResult(statistic=0.30570032095155825, pvalue=0.7601313863865756)

# %% [markdown]
# ## Dependant Sample-Paired T-Test
#
# ### Same Group (Male) but different Condition (ssc_p,hsc_p)

# %%
# Hypothesis testing

# %%
# Statement: Test whether SSC_p of male and HSC_p of Male is Same?

# %%
# Null hypothesis=There is no similarly between 10th pass mark of male and 12th pass mark of male.

# %%
from scipy.stats import ttest_rel
dataset=dataset.dropna()
male = dataset[dataset['gender']=='M']["ssc_p"]
male1 = dataset[dataset['gender']=='M']["hsc_p"]
#print(MALE)
ttest_rel(male,male1)
# Out:
# Ttest_relResult(statistic=0.6842940392688153, pvalue=0.4949370716000775)

# %% [markdown]
# ## Reject Null Hypothesis When p<0.05
#
# ## Accept Null Hyothesis and Reject Alternate Hypothesis.
#
# ## ANAVO: Analysis of Variance

# %%
import scipy.stats as stats

stats.f_oneway(dataset['ssc_p'],dataset['hsc_p'],dataset['degree_p'])
# Out:
# F_onewayResult(statistic=0.695991304348204, pvalue=0.49895574725815317)

# %%
#The salary is significant so it accept H1 and reject H0
#The salary is not significant so it accept H0 and reject H1

# %% [markdown]
# ## Two Way Anova

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
# two-way ANOVA
anov=ols("mba_p~salary+status",data=dataset).fit()

# %%
TWA=sm.stats.anova_lm(anov,type=2)

# %%
TWA
# Out:
#              df       sum_sq     mean_sq         F    PR(>F)
# status      1.0    43.087586   43.087586  1.294503  0.256504
# salary      1.0   182.556468  182.556468  5.484640  0.020112
# Residual  212.0  7056.428339   33.285039       NaN       NaN

# %%
#The salary is significant so it accept H1 and reject H0
#The salary is not significant so it accept H0 and reject H1

# %%
#Homoscedasticity  - is an assumption of equal or similar variances in different groups being compared .

#Heteroscedasticity - is an assumption of different variance in different group being compared .

#Homoscedasticity is better
